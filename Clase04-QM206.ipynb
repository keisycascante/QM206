# %% [markdown]
# <a href="https://colab.research.google.com/github/keisycascante/QM206/blob/main/Clase04-QM206.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.random.randn(100)
y=np.random.randn(100)
df=pd.DataFrame({"X":x, "Y":y})
df.head(10)
df.tail(10)
# Out:
#            X         Y
# 90 -2.479440 -0.955471
# 91 -0.470287 -0.574171
# 92  0.988723 -1.327304
# 93  0.117708  2.352023
# 94 -0.970693  0.158355
# 95  1.727921 -2.228405
# 96 -0.307211  1.172402
# 97 -0.838432  2.649510
# 98  0.221267  0.374656
# 99 -1.318380 -0.440934

# %% [markdown]
# DataFrame= tabla de datos

# %% [markdown]
# ({"X":x, "Y":y}) = diccionario

# %%
nombre=["José", "Juan", "Mario", "Carlos", "María"]
edad=[24, 34, 12, 23, 25]
altura=[180, 175, 156, 187, 145]
dict2={"Nombre": nombre, "Edad": edad, "Altura": altura}
datos2=pd.DataFrame
df.head(5)
# Out:
#           X         Y
# 0  0.353454 -1.625208
# 1 -1.743101 -0.256640
# 2  0.441862 -0.045822
# 3 -0.631706 -1.911298
# 4 -1.053137  0.512513

# %%
name=["Hidrógeno", "Helio", "Litio", "Berilio", "Boro"]
sb=["H", "He", "Li", "Be", "B"]
an=[1,2,3,4,5]
aw=[1.00, 2.00, 6.94, 9.02, 10.8]
dict3={"Name":name,"Symbol":sb,"Atomic Number":an,"Atomic Weight":aw}
datos3=pd.DataFrame(dict3)
datos3.head()
# Out:
#         Name Symbol  Atomic Number  Atomic Weight
# 0  Hidrógeno      H              1           1.00
# 1      Helio     He              2           2.00
# 2      Litio     Li              3           6.94
# 3    Berilio     Be              4           9.02
# 4       Boro      B              5          10.80

# %%
url="https://raw.githubusercontent.com/PedroGonzalezBeermann2020/QM206/refs/heads/main/CH4.csv"
data=pd.read_csv(url)
data.tail(10)
# Out:
#      TempK       Cp        S    Scalc        H   deltaH   deltaG  logKf
# 54  5100.0  105.642  400.794  314.414  440.541  -96.157  476.722 -4.883
# 55  5200.0  105.733  402.847  316.095  451.110  -96.703  487.961 -4.902
# 56  5300.0  105.818  404.861  317.750  461.688  -97.278  499.210 -4.920
# 57  5400.0  105.899  406.840  319.382  472.274  -97.882  510.470 -4.938
# 58  5500.0  105.976  408.784  320.990  482.867  -98.513  521.741 -4.955
# 59  5600.0  106.049  410.694  322.575  493.469  -99.170  533.025 -4.972
# 60  5700.0  106.118  412.572  324.137  504.077  -99.852  544.320 -4.988
# 61  5800.0  106.184  414.418  325.678  514.692 -100.557  555.628 -5.004
# 62  5900.0  106.247  416.234  327.197  525.314 -101.284  566.946 -5.019
# 63  6000.0  106.306  418.020  328.696  535.942 -102.032  578.279 -5.034

# %%
T=data["TempK"]
Cp=data["Cp"]
plt.plot(T,Cp)
plt.xlabel("Temperatura (K)")
plt.ylabel("Cp")
plt.title("Cp vs Temperatura K")
plt.show()

# %%
data["Cp"]
# Out:
# 0      33.258
# 1      33.473
# 2      34.216
# 3      35.639
# 4      35.708
#        ...
# 59    106.049
# 60    106.118
# 61    106.184
# 62    106.247
# 63    106.306
# Name: Cp, Length: 64, dtype: float64

# %%
data.columns
# Out:
# Index(['TempK', 'Cp', 'S', 'Scalc', 'H', 'deltaH', 'deltaG', 'logKf'], dtype='object')

# %%
data.index
# Out:
# RangeIndex(start=0, stop=64, step=1)

# %%
data.shape[1]
# Out:
# 8

# %%
url2="https://raw.githubusercontent.com/PedroGonzalezBeermann2020/QM206/refs/heads/main/Titulacion.csv"
data2=pd.read_csv(url2)
data2.head()
# Out:
#    mLNaOH   pH
# 0       0  2.8
# 1       1  3.5
# 2       2  3.8
# 3       3  4.6
# 4       4  6.8

# %%
plt.plot(data2["mLNaOH"],data2["pH"])
plt.grid()
plt.xlabel("mL NaOH")
plt.ylabel("pH")
plt.title("pH vs mL NaOH")
plt.show()

# %%
data2.loc[data2["pH"]<3.8]
# Out:
#    mLNaOH   pH
# 0       0  2.8
# 1       1  3.5

# %%
urlO2="https://raw.githubusercontent.com/PedroGonzalezBeermann2020/QM206/refs/heads/main/O2.csv"
data02=pd.read_csv(urlO2)
data02.head()
# Out:
#        TK      Cp        S    Scalc      H
# 0  100.00  29.106  173.307  231.094 -5.779
# 1  200.00  29.126  193.485  207.823 -2.868
# 2  250.00  29.201  199.990  205.630 -1.410
# 3  298.15  29.376  205.147  205.147  0.000
# 4  300.00  29.385  205.329  205.148  0.054

# %%
urlO2="https://raw.githubusercontent.com/PedroGonzalezBeermann2020/QM206/refs/heads/main/O2.csv"

# %%
dataO2=pd.read_csv(urlO2)
dataO2.head()
# Out:
#        TK      Cp        S    Scalc      H
# 0  100.00  29.106  173.307  231.094 -5.779
# 1  200.00  29.126  193.485  207.823 -2.868
# 2  250.00  29.201  199.990  205.630 -1.410
# 3  298.15  29.376  205.147  205.147  0.000
# 4  300.00  29.385  205.329  205.148  0.054

# %%
plt.plot(dataO2["TK"],dataO2["S"])
plt.grid()
plt.xlabel("Temperatura (K)")
plt.ylabel("Entropía (atm)")
plt.title("Entropía vs Temperatura(K)")
plt.show()

# %%
urlTabla="https://gist.githubusercontent.com/GoodmanSciences/c2dd862cd38f21b0ad36b8f96b4bf1ee/raw/1d92663004489a5b6926e944c1b3d9ec5c40900e/Periodic%2520Table%2520of%2520Elements.csv"
dataTabla=pd.read_csv(urlTabla)
dataTabla.head()
# Out:
#    AtomicNumber    Element Symbol  AtomicMass  NumberofNeutrons  \
# 0             1   Hydrogen      H       1.007                 0
# 1             2     Helium     He       4.002                 2
# 2             3    Lithium     Li       6.941                 4
# 3             4  Beryllium     Be       9.012                 5
# 4             5      Boron      B      10.811                 6
#
#    NumberofProtons  NumberofElectrons  Period  Group  Phase  ...  \
# 0                1                  1       1    1.0    gas  ...
# 1                2                  2       1   18.0    gas  ...
# 2                3                  3       2    1.0  solid  ...
# 3                4                  4       2    2.0  solid  ...
# 4                5                  5       2   13.0  solid  ...
#
#   FirstIonization   Density MeltingPoint BoilingPoint NumberOfIsotopes  \
# 0         13.5984  0.000090       14.175        20.28              3.0
# ...

# %%
dataTabla.head()
# Out:
#    AtomicNumber    Element Symbol  AtomicMass  NumberofNeutrons  \
# 0             1   Hydrogen      H       1.007                 0
# 1             2     Helium     He       4.002                 2
# 2             3    Lithium     Li       6.941                 4
# 3             4  Beryllium     Be       9.012                 5
# 4             5      Boron      B      10.811                 6
#
#    NumberofProtons  NumberofElectrons  Period  Group  Phase  ...  \
# 0                1                  1       1    1.0    gas  ...
# 1                2                  2       1   18.0    gas  ...
# 2                3                  3       2    1.0  solid  ...
# 3                4                  4       2    2.0  solid  ...
# 4                5                  5       2   13.0  solid  ...
#
#   FirstIonization   Density MeltingPoint BoilingPoint NumberOfIsotopes  \
# 0         13.5984  0.000090       14.175        20.28              3.0
# ...

# %%
dataTabla.columns
# Out:
# Index(['AtomicNumber', 'Element', 'Symbol', 'AtomicMass', 'NumberofNeutrons',
#        'NumberofProtons', 'NumberofElectrons', 'Period', 'Group', 'Phase',
#        'Radioactive', 'Natural', 'Metal', 'Nonmetal', 'Metalloid', 'Type',
#        'AtomicRadius', 'Electronegativity', 'FirstIonization', 'Density',
#        'MeltingPoint', 'BoilingPoint', 'NumberOfIsotopes', 'Discoverer',
#        'Year', 'SpecificHeat', 'NumberofShells', 'NumberofValence'],
#       dtype='object')

# %%
dataTabla.shape
# Out:
# (118, 28)

# %%
dataTabla.dtypes
# Out:
# AtomicNumber           int64
# Element               object
# Symbol                object
# AtomicMass           float64
# NumberofNeutrons       int64
# NumberofProtons        int64
# NumberofElectrons      int64
# Period                 int64
# Group                float64
# Phase                 object
# Radioactive           object
# Natural               object
# Metal                 object
# Nonmetal              object
# Metalloid             object
# Type                  object
# AtomicRadius         float64
# Electronegativity    float64
# FirstIonization      float64
# Density              float64
# MeltingPoint         float64
# BoilingPoint         float64
# NumberOfIsotopes     float64
# Discoverer            object
# Year                 float64
# SpecificHeat         float64
# NumberofShells         int64
# NumberofValence      float64
# dtype: object

# %%
plt.plot(dataTabla["AtomicNumber"],dataTabla["Electronegativity"])
plt.grid()
plt.xlabel("Número atómico")
plt.ylabel("Electronegatividad")
plt.title("Electronegatividad vs Número atómico")
plt.show()
